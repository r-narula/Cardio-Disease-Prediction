# %%
import pycaret
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/mononoke/Desktop/Gautam Project/framingham.csv")
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# ## Preprocessing

# %%
df = df.dropna()
df.isna().sum()
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4237       80.0    107.0           0
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0
#
# [3658 rows x 16 columns]

# %%
df = df.drop(df[df.totChol > 599].index)
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4237       80.0    107.0           0
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0
#
# [3657 rows x 16 columns]

# %%
from sklearn.utils import shuffle
df = shuffle(df,random_state=42)

# %% [markdown]
# ## Pycaret

# %%
from pycaret.classification import *
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)

# %%
best = compare_models()
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr  Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395  0.1108
#
#        MCC  TT (Sec)
# lr  0.1861     0.997
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395  0.1108
# knn  K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142  0.1329  0.0750
#
#         MCC  TT (Sec)
# lr   0.1861     0.997
# knn  0.0945     0.081
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395  0.1108
# knn  K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142  0.1329  0.0750
# nb              Naive Bayes    0.8206  0.7081  0.2032  0.3332  0.2495  0.1563
#
#         MCC  TT (Sec)
# lr   0.1861     0.997
# knn  0.0945     0.081
# nb   0.1630     0.021
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395
# knn    K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142  0.1329
# nb                Naive Bayes    0.8206  0.7081  0.2032  0.3332  0.2495
# dt   Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432  0.2479
#
#       Kappa     MCC  TT (Sec)
# lr   0.1108  0.1861     0.997
# knn  0.0750  0.0945     0.081
# nb   0.1563  0.1630     0.021
# dt   0.1114  0.1117     0.039
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395
# knn    K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142  0.1329
# nb                Naive Bayes    0.8206  0.7081  0.2032  0.3332  0.2495
# svm       SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030  0.1064
# dt   Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432  0.2479
#
#       Kappa     MCC  TT (Sec)
# lr   0.1108  0.1861     0.997
# knn  0.0750  0.0945     0.081
# nb   0.1563  0.1630     0.021
# svm  0.0527  0.0950     0.026
# dt   0.1114  0.1117     0.039
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr          Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395
# ridge          Ridge Classifier    0.8519  0.0000  0.0258  0.6250  0.0490
# knn      K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142  0.1329
# nb                  Naive Bayes    0.8206  0.7081  0.2032  0.3332  0.2495
# svm         SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030  0.1064
# dt     Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432  0.2479
#
#         Kappa     MCC  TT (Sec)
# lr     0.1108  0.1861     0.997
# ridge  0.0392  0.1064     0.014
# knn    0.0750  0.0945     0.081
# nb     0.1563  0.1630     0.021
# svm    0.0527  0.0950     0.026
# dt     0.1114  0.1117     0.039
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr          Logistic Regression    0.8546  0.7214  0.0804  0.6471  0.1395
# ridge          Ridge Classifier    0.8519  0.0000  0.0258  0.6250  0.0490
# rf     Random Forest Classifier    0.8468  0.6891  0.0443  0.4217  0.0782
# knn      K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142  0.1329
# nb                  Naive Bayes    0.8206  0.7081  0.2032  0.3332  0.2495
# svm         SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030  0.1064
# dt     Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432  0.2479
#
#         Kappa     MCC  TT (Sec)
# lr     0.1108  0.1861     0.997
# ridge  0.0392  0.1064     0.014
# rf     0.0516  0.0913     0.335
# knn    0.0750  0.0945     0.081
# nb     0.1563  0.1630     0.021
# svm    0.0527  0.0950     0.026
# dt     0.1114  0.1117     0.039
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                 Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# rf            Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# knn             K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda    Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                         Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt            Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.1395  0.1108  0.1861     0.997
# ridge  0.0490  0.0392  0.1064     0.014
# rf     0.0782  0.0516  0.0913     0.335
# knn    0.1329  0.0750  0.0945     0.081
# qda    0.2299  0.1440  0.1529     0.039
# nb     0.2495  0.1563  0.1630     0.021
# svm    0.1064  0.0527  0.0950     0.026
# dt     0.2479  0.1114  0.1117     0.039
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                 Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# rf            Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# ada               Ada Boost Classifier    0.8394  0.6758  0.0833  0.3324
# knn             K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda    Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                         Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt            Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.1395  0.1108  0.1861     0.997
# ridge  0.0490  0.0392  0.1064     0.014
# rf     0.0782  0.0516  0.0913     0.335
# ada    0.1310  0.0805  0.1029     0.097
# knn    0.1329  0.0750  0.0945     0.081
# qda    0.2299  0.1440  0.1529     0.039
# nb     0.2495  0.1563  0.1630     0.021
# svm    0.1064  0.0527  0.0950     0.026
# dt     0.2479  0.1114  0.1117     0.039
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                 Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# rf            Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# ada               Ada Boost Classifier    0.8394  0.6758  0.0833  0.3324
# gbc       Gradient Boosting Classifier    0.8390  0.6811  0.0600  0.3081
# knn             K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda    Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                         Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt            Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.1395  0.1108  0.1861     0.997
# ridge  0.0490  0.0392  0.1064     0.014
# rf     0.0782  0.0516  0.0913     0.335
# ada    0.1310  0.0805  0.1029     0.097
# gbc    0.0989  0.0545  0.0764     0.224
# knn    0.1329  0.0750  0.0945     0.081
# qda    0.2299  0.1440  0.1529     0.039
# nb     0.2495  0.1563  0.1630     0.021
# svm    0.1064  0.0527  0.0950     0.026
# dt     0.2479  0.1114  0.1117     0.039
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                 Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# lda       Linear Discriminant Analysis    0.8496  0.7188  0.0962  0.5260
# rf            Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# ada               Ada Boost Classifier    0.8394  0.6758  0.0833  0.3324
# gbc       Gradient Boosting Classifier    0.8390  0.6811  0.0600  0.3081
# knn             K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda    Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                         Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt            Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.1395  0.1108  0.1861     0.997
# ridge  0.0490  0.0392  0.1064     0.014
# lda    0.1575  0.1168  0.1700     0.029
# rf     0.0782  0.0516  0.0913     0.335
# ada    0.1310  0.0805  0.1029     0.097
# gbc    0.0989  0.0545  0.0764     0.224
# knn    0.1329  0.0750  0.0945     0.081
# qda    0.2299  0.1440  0.1529     0.039
# nb     0.2495  0.1563  0.1630     0.021
# svm    0.1064  0.0527  0.0950     0.026
# dt     0.2479  0.1114  0.1117     0.039
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                 Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# lda       Linear Discriminant Analysis    0.8496  0.7188  0.0962  0.5260
# rf            Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# et              Extra Trees Classifier    0.8410  0.6660  0.0311  0.2217
# ada               Ada Boost Classifier    0.8394  0.6758  0.0833  0.3324
# gbc       Gradient Boosting Classifier    0.8390  0.6811  0.0600  0.3081
# knn             K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda    Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                         Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt            Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.1395  0.1108  0.1861     0.997
# ridge  0.0490  0.0392  0.1064     0.014
# lda    0.1575  0.1168  0.1700     0.029
# rf     0.0782  0.0516  0.0913     0.335
# et     0.0531  0.0231  0.0337     0.243
# ada    0.1310  0.0805  0.1029     0.097
# gbc    0.0989  0.0545  0.0764     0.224
# knn    0.1329  0.0750  0.0945     0.081
# qda    0.2299  0.1440  0.1529     0.039
# nb     0.2495  0.1563  0.1630     0.021
# svm    0.1064  0.0527  0.0950     0.026
# dt     0.2479  0.1114  0.1117     0.039
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                    Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# lda          Linear Discriminant Analysis    0.8496  0.7188  0.0962  0.5260
# rf               Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# et                 Extra Trees Classifier    0.8410  0.6660  0.0311  0.2217
# ada                  Ada Boost Classifier    0.8394  0.6758  0.0833  0.3324
# gbc          Gradient Boosting Classifier    0.8390  0.6811  0.0600  0.3081
# lightgbm  Light Gradient Boosting Machine    0.8351  0.6346  0.0810  0.3091
# knn                K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda       Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                            Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                   SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt               Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.1395  0.1108  0.1861     0.997
# ridge     0.0490  0.0392  0.1064     0.014
# lda       0.1575  0.1168  0.1700     0.029
# rf        0.0782  0.0516  0.0913     0.335
# et        0.0531  0.0231  0.0337     0.243
# ada       0.1310  0.0805  0.1029     0.097
# gbc       0.0989  0.0545  0.0764     0.224
# lightgbm  0.1267  0.0706  0.0898     0.077
# knn       0.1329  0.0750  0.0945     0.081
# qda       0.2299  0.1440  0.1529     0.039
# nb        0.2495  0.1563  0.1630     0.021
# svm       0.1064  0.0527  0.0950     0.026
# dt        0.2479  0.1114  0.1117     0.039
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.8546  0.7214  0.0804  0.6471
# ridge                    Ridge Classifier    0.8519  0.0000  0.0258  0.6250
# lda          Linear Discriminant Analysis    0.8496  0.7188  0.0962  0.5260
# rf               Random Forest Classifier    0.8468  0.6891  0.0443  0.4217
# et                 Extra Trees Classifier    0.8410  0.6660  0.0311  0.2217
# ada                  Ada Boost Classifier    0.8394  0.6758  0.0833  0.3324
# gbc          Gradient Boosting Classifier    0.8390  0.6811  0.0600  0.3081
# lightgbm  Light Gradient Boosting Machine    0.8351  0.6346  0.0810  0.3091
# knn                K Neighbors Classifier    0.8347  0.6161  0.0859  0.3142
# qda       Quadratic Discriminant Analysis    0.8245  0.7067  0.1824  0.3314
# nb                            Naive Bayes    0.8206  0.7081  0.2032  0.3332
# svm                   SVM - Linear Kernel    0.7777  0.0000  0.1494  0.4030
# dt               Decision Tree Classifier    0.7679  0.5568  0.2549  0.2432
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.1395  0.1108  0.1861     0.997
# ridge     0.0490  0.0392  0.1064     0.014
# lda       0.1575  0.1168  0.1700     0.029
# rf        0.0782  0.0516  0.0913     0.335
# et        0.0531  0.0231  0.0337     0.243
# ada       0.1310  0.0805  0.1029     0.097
# gbc       0.0989  0.0545  0.0764     0.224
# lightgbm  0.1267  0.0706  0.0898     0.077
# knn       0.1329  0.0750  0.0945     0.081
# qda       0.2299  0.1440  0.1529     0.039
# nb        0.2495  0.1563  0.1630     0.021
# svm       0.1064  0.0527  0.0950     0.026
# dt        0.2479  0.1114  0.1117     0.039

# %% [markdown]
# ## Model Training

# %%
# ### Standarization
# from sklearn.preprocessing import StandardScaler
# scale = StandardScaler()

# X = scale.fit_transform(df.iloc[:2500,:15])
# Y = df.iloc[:2500,-1]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=42)
# clf = RidgeClassifier(max_iter=10)

clf.fit(df.iloc[:2500,:15],df.iloc[:2500,-1])
ypred = clf.predict(df.iloc[1500:,:15])

# %%
df.iloc[1500:,-1].tolist()
# Out:
# 2907    0
# 3682    0
# 2698    0
# 2575    0
# 574     0
#        ..
# 1308    0
# 1495    0
# 987     0
# 4073    0
# 3693    0
# Name: TenYearCHD, Length: 2157, dtype: int64

# %%
count = 0
for i in range(len(ypred)):
    if ypred[i] != Y.tolist()[i]:
        count += 1

print((len(ypred)-count)/len(ypred))
# Out:
# 0.8433008808530367
